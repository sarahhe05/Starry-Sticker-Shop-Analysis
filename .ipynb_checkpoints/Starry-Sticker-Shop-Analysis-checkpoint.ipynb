# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
import numpy as np
from brokenaxes import brokenaxes
from wordcloud import WordCloud
from textblob import TextBlob
import random
import geopandas as gpd
from matplotlib.colors import LinearSegmentedColormap, Normalize
from matplotlib.patches import Patch
from matplotlib import cm
from collections import Counter
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
import re

# %%
import os

print(os.listdir(r'D:/Code/Starry-Sticker-Shop-Analysis'))
# Out:
# ['.git', '.ipynb_checkpoints', 'all_data.csv', 'color palette.png', 'EtsyListingsDownload.csv', 'EtsySoldOrderItems2020.csv', 'EtsySoldOrderItems2021.csv', 'EtsySoldOrderItems2022.csv', 'EtsySoldOrderItems2023.csv', 'logo.png', 'ne_110m_admin_0_countries', 'ne_110m_admin_1_states_provinces', 'README.md', 'reviews.json', 'review_count.csv', 'sentiment_category.csv', 'Starry-Sticker-Shop-Analysis.ipynb', 'Starry-Sticker-Shop-Analysis.twb', 'state_count.csv', '~Starry-Sticker-Shop-Analysis__12008.twbr']

# %% [markdown]
# **Importing data from CSV files.**

# %%
orders_2020_df = pd.read_csv('D:/Code/Starry-Sticker-Shop-Analysis/EtsySoldOrderItems2020.csv')
orders_2021_df = pd.read_csv('D:/Code/Starry-Sticker-Shop-Analysis/EtsySoldOrderItems2021.csv')
orders_2022_df = pd.read_csv('D:/Code/Starry-Sticker-Shop-Analysis/EtsySoldOrderItems2022.csv')
orders_2023_df = pd.read_csv('D:/Code/Starry-Sticker-Shop-Analysis/EtsySoldOrderItems2023.csv')
reviews_df = pd.read_json('D:/Code/Starry-Sticker-Shop-Analysis/reviews.json')

# %%
print(orders_2020_df.columns)
# Out:
# Index(['Sale Date', 'Item Name', 'Buyer', 'Quantity', 'Price', 'Coupon Code',
#        'Coupon Details', 'Discount Amount', 'Shipping Discount',
#        'Order Shipping', 'Order Sales Tax', 'Item Total', 'Currency',
#        'Transaction ID', 'Listing ID', 'Date Paid', 'Date Shipped',
#        'Ship Name', 'Ship Address1', 'Ship Address2', 'Ship City',
#        'Ship State', 'Ship Zipcode', 'Ship Country', 'Order ID', 'Variations',
#        'Order Type', 'Listings Type', 'Payment Type', 'InPerson Discount',
#        'InPerson Location', 'VAT Paid by Buyer', 'SKU'],
#       dtype='object')

# %%
orders_df = pd.concat([orders_2020_df, orders_2021_df, orders_2022_df, orders_2023_df])

# %%
orders_df
# Out:
#    Sale Date                                          Item Name  \
# 0   12/31/20  quali-tea boba | stickers, boba stickers, bull...
# 1   12/31/20  breakfast time | stickers, food stickers, bull...
# 2   12/30/20  quali-tea boba | stickers, boba stickers, bull...
# 3   12/30/20  breakfast time | stickers, food stickers, bull...
# 4   12/29/20  journey into outer space | stickers, planet st...
# ..       ...                                                ...
# 55  01/01/22  back to school essentials | sticker flakes, st...
# 0   06/22/23  back to school essentials | sticker flakes, st...
# 1   05/10/23  back to school essentials | sticker flakes, st...
# 2   02/26/23  breakfast time | sticker flakes stickers, food...
# 3   01/19/23  breakfast time | sticker flakes stickers, food...
#
#                                      Buyer  Quantity  Price Coupon Code  \
# 0                Stephanie Nguyen (skn525)         1   4.50         NaN
# 1                Stephanie Nguyen (skn525)         1   3.30         NaN
# 2                                      NaN         1   4.50         NaN
# 3                      Isabella (hb7l2hvu)         1   3.30         NaN
# 4                              picklewood8         1   3.25         NaN
# ..                                     ...       ...    ...         ...
# 55                      Abigail (jtcvnvjq)         1   3.00         NaN
# 0                        domoniquebradley1         1   3.00         NaN
# 1                 Marie D Leon (marie123d)         1   3.00         NaN
# 2   ReallyKoolCreations (kihu6xrvdvfum6z9)         1   3.30         NaN
# 3                Teresa (i2mhargfaqkfi7cx)         1   3.30         NaN
#
#    Coupon Details  Discount Amount  Shipping Discount  Order Shipping  ...  \
# 0             NaN              0.0                0.0             0.0  ...
# 1             NaN              0.0                0.0             0.0  ...
# 2             NaN              0.0                0.0             0.0  ...
# 3             NaN              0.0                0.0             0.0  ...
# 4             NaN              0.0                0.0             0.0  ...
# ..            ...              ...                ...             ...  ...
# 55            NaN              0.0                0.0             0.0  ...
# 0             NaN              0.0                0.0             0.0  ...
# 1             NaN              0.0                0.0             0.0  ...
# 2             NaN              0.0                0.0             0.0  ...
# 3             NaN              0.0                0.0             0.0  ...
#
#      Ship Country    Order ID  Variations  Order Type  Listings Type  \
# 0   United States  1899977282  Size:Small      online        listing
# 1   United States  1899977282         NaN      online        listing
# 2   United States  1899823336  Size:Small      online        listing
# 3   United States  1899150138         NaN      online        listing
# 4   United States  1898550322         NaN      online        listing
# ..            ...         ...         ...         ...            ...
# 55  United States  2329488425         NaN      online        listing
# 0   United States  2931837964         NaN      online        listing
# 1   United States  2884157195         NaN      online        listing
# 2   United States  2805945627         NaN      online        listing
# 3   United States  2764068303         NaN      online        listing
#
#    Payment Type InPerson Discount InPerson Location VAT Paid by Buyer SKU
# 0     online_cc               NaN               NaN                 0 NaN
# 1     online_cc               NaN               NaN                 0 NaN
# 2     online_cc               NaN               NaN                 0 NaN
# 3     online_cc               NaN               NaN                 0 NaN
# 4     online_cc               NaN               NaN                 0 NaN
# ..          ...               ...               ...               ...  ..
# 55    online_cc               NaN               NaN                 0 NaN
# 0     online_cc               NaN               NaN                 0 NaN
# 1     online_cc               NaN               NaN                 0 NaN
# 2     online_cc               NaN               NaN                 0 NaN
# 3     online_cc               NaN               NaN                 0 NaN
#
# [266 rows x 33 columns]

# %%
reviews_df
# Out:
#              reviewer date_reviewed  star_rating  \
# 0   domoniquebradley1    07/12/2023            5
# 1              Vinnie    12/11/2022            4
# 2               Emery    12/10/2022            5
# 3            aeostria    10/22/2022            5
# 4            Margaret    07/20/2022            4
# ..                ...           ...          ...
# 78            Lindsey    08/27/2020            5
# 79            Lindsey    08/27/2020            5
# 80              Kacie    08/19/2020            5
# 81               Hope    08/15/2020            5
# 82               Hope    07/28/2020            5
#
#                                               message    order_id
# 0   Revised: Seller reached out to me to send anot...  2931837964
# 1                                                      2672096215
# 2   Love the stickers! All the designs are super c...  2675093852
# 3                                                      2576362568
# 4   The designs are so cute and they are a perfect...  2495438828
# ..                                                ...         ...
# 78             supa cute! definitely buying again! <3  1745068953
# 79                                love these so much!  1745068953
# 80               there are so many adorable stickers!  1731548983
# 81                                                     1722218714
# 82  Love them so much!! They are so cute and awesome!  1716085261
#
# [83 rows x 5 columns]

# %% [markdown]
# **Data Cleaning**
# -
# - Merge Order Item DataFrames and Reviews DataFrame
# - Drop irrelevant columns
# - Split "Item Name" column into "Item" and "Tags"
# - Convert dates of various formats to datetime objects
# - Convert state and country names to consistent format

# %%
#merge orders_df with reviews_df
reviews_df.rename(columns={'order_id': 'Order ID'}, inplace=True)
all_df = pd.merge(orders_df, reviews_df, on='Order ID', how='left')

# %%
all_df
# Out:
#     Sale Date                                          Item Name  \
# 0    12/31/20  quali-tea boba | stickers, boba stickers, bull...
# 1    12/31/20  breakfast time | stickers, food stickers, bull...
# 2    12/30/20  quali-tea boba | stickers, boba stickers, bull...
# 3    12/30/20  breakfast time | stickers, food stickers, bull...
# 4    12/29/20  journey into outer space | stickers, planet st...
# ..        ...                                                ...
# 278  01/01/22  back to school essentials | sticker flakes, st...
# 279  06/22/23  back to school essentials | sticker flakes, st...
# 280  05/10/23  back to school essentials | sticker flakes, st...
# 281  02/26/23  breakfast time | sticker flakes stickers, food...
# 282  01/19/23  breakfast time | sticker flakes stickers, food...
#
#                                       Buyer  Quantity  Price Coupon Code  \
# 0                 Stephanie Nguyen (skn525)         1   4.50         NaN
# 1                 Stephanie Nguyen (skn525)         1   3.30         NaN
# 2                                       NaN         1   4.50         NaN
# 3                       Isabella (hb7l2hvu)         1   3.30         NaN
# 4                               picklewood8         1   3.25         NaN
# ..                                      ...       ...    ...         ...
# 278                      Abigail (jtcvnvjq)         1   3.00         NaN
# 279                       domoniquebradley1         1   3.00         NaN
# 280                Marie D Leon (marie123d)         1   3.00         NaN
# 281  ReallyKoolCreations (kihu6xrvdvfum6z9)         1   3.30         NaN
# 282               Teresa (i2mhargfaqkfi7cx)         1   3.30         NaN
#
#     Coupon Details  Discount Amount  Shipping Discount  Order Shipping  ...  \
# 0              NaN              0.0                0.0             0.0  ...
# 1              NaN              0.0                0.0             0.0  ...
# 2              NaN              0.0                0.0             0.0  ...
# 3              NaN              0.0                0.0             0.0  ...
# 4              NaN              0.0                0.0             0.0  ...
# ..             ...              ...                ...             ...  ...
# 278            NaN              0.0                0.0             0.0  ...
# 279            NaN              0.0                0.0             0.0  ...
# 280            NaN              0.0                0.0             0.0  ...
# 281            NaN              0.0                0.0             0.0  ...
# 282            NaN              0.0                0.0             0.0  ...
#
#      Listings Type  Payment Type InPerson Discount  InPerson Location  \
# 0          listing     online_cc               NaN                NaN
# 1          listing     online_cc               NaN                NaN
# 2          listing     online_cc               NaN                NaN
# 3          listing     online_cc               NaN                NaN
# 4          listing     online_cc               NaN                NaN
# ..             ...           ...               ...                ...
# 278        listing     online_cc               NaN                NaN
# 279        listing     online_cc               NaN                NaN
# 280        listing     online_cc               NaN                NaN
# 281        listing     online_cc               NaN                NaN
# 282        listing     online_cc               NaN                NaN
#
#      VAT Paid by Buyer SKU           reviewer date_reviewed star_rating  \
# 0                    0 NaN                NaN           NaN         NaN
# 1                    0 NaN                NaN           NaN         NaN
# 2                    0 NaN                NaN           NaN         NaN
# 3                    0 NaN                NaN           NaN         NaN
# 4                    0 NaN                NaN           NaN         NaN
# ..                 ...  ..                ...           ...         ...
# 278                  0 NaN                NaN           NaN         NaN
# 279                  0 NaN  domoniquebradley1    07/12/2023         5.0
# 280                  0 NaN                NaN           NaN         NaN
# 281                  0 NaN                NaN           NaN         NaN
# 282                  0 NaN                NaN           NaN         NaN
#
#                                                message
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 278                                                NaN
# 279  Revised: Seller reached out to me to send anot...
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
#
# [283 rows x 37 columns]

# %%
#drop irrelevant columns
all_df = all_df.drop(columns= ['Buyer', 'Coupon Code', 'Coupon Details', 'Discount Amount', 'Shipping Discount', 'Order Shipping', 'Order Sales Tax', 
                              'Currency', 'Transaction ID', 'Listing ID', 'Date Paid', 'Ship Address1', 'Ship Address2', 'Ship City', 'Ship Zipcode', 'Order ID', 
                              'Order Type', 'Listings Type', 'Payment Type', 'InPerson Discount', 'InPerson Location', 'VAT Paid by Buyer', 'SKU', 
                                     'reviewer', 'date_reviewed'])
all_df.rename(columns={'star_rating': 'Rating'}, inplace=True)
all_df.rename(columns={'message': 'Review'}, inplace=True)

# %%
print(all_df['Item Name'].unique())
# Out:
# ['quali-tea boba | stickers, boba stickers, bullet journal, stationery, crafts, pen pal, planners'
#  'breakfast time | stickers, food stickers, bullet journal, stationery, crafts, pen pal, planners'
#  'journey into outer space | stickers, planet stickers, bullet journal, stationery, crafts, pen pal, planners'
#  'a starry christmas | stickers, christmas stickers, bullet journal, stationery, crafts, pen pal, planners'
#  'a starry christmas | stickers, food stickers, bullet journal, stationery, crafts, pen pal, planners'
#  '31 days of boba | stickers, boba stickers, bullet journal, stationery, crafts, pen pal, planners'
#  'journey into outer space | sticker flakes, stickers, planet stickers, bullet journal, stationery, crafts, pen pal, planners'
#  'a starry christmas | sticker flakes, stickers, christmas stickers, bullet journal, stationery, crafts, pen pal, planners'
#  'breakfast time | sticker flakes stickers, food stickers, bullet journal, stationery, crafts, pen pal, planners'
#  'holiday cookies | sticker flakes, stickers, food stickers, holiday stickers, bullet journal, stationery, crafts, pen pal, planners'
#  'quali-tea boba | sticker flakes, stickers, boba stickers, bullet journal, stationery, crafts, pen pal, planners'
#  'back to school essentials | sticker flakes, stickers, school stickers, bullet journal, stationery, crafts, pen pal, planners'
#  'breakfast time | sticker sheet, stickers, food stickers, bullet journal, stationery, crafts, pen pal, planners'
#  'journey into outer space | sticker sheet, stickers, planet stickers, bullet journal, stationery, crafts, pen pal, planners'
#  'back to school essentials | stickers, school stickers, bullet journal, stationery, crafts, pen pal, planners'
#  '31 days of boba | sticker flakes, stickers, boba stickers, bullet journal, stationery, crafts, pen pal, planners']

# %%
#split 'Item Name' column into 'Item' and 'Tags'
def split_custom_data(row):
    parts = row['Item Name'].split(' | ')
    return pd.Series({'Item': parts[0], 'Tags': parts[1]})

all_df[['Item', 'Tags']] = all_df.apply(split_custom_data, axis=1)
all_df = all_df.drop(columns="Item Name")

# %%
def titlecase(text):
    return text.title()

all_df['Item'] = all_df.get('Item').apply(titlecase)

# %%
pd.set_option('display.max_rows', 5)  #show all rows
pd.set_option('display.max_columns', 15)  #show all columns
all_df
# Out:
#     Sale Date  Quantity  Price  Item Total Date Shipped           Ship Name  \
# 0    12/31/20         1    4.5         4.5   01/04/2021    Stephanie Nguyen
# 1    12/31/20         1    3.3         3.3   01/04/2021    Stephanie Nguyen
# ..        ...       ...    ...         ...          ...                 ...
# 281  02/26/23         1    3.3         3.3   03/05/2023  Tiffany SantaMaria
# 282  01/19/23         1    3.3         3.3   01/28/2023         Teresa bone
#
#     Ship State   Ship Country  Variations  Rating Review            Item  \
# 0           CA  United States  Size:Small     NaN    NaN  Quali-Tea Boba
# 1           CA  United States         NaN     NaN    NaN  Breakfast Time
# ..         ...            ...         ...     ...    ...             ...
# 281         AZ  United States         NaN     NaN    NaN  Breakfast Time
# 282         SC  United States         NaN     NaN    NaN  Breakfast Time
#
#                                                   Tags
# 0    stickers, boba stickers, bullet journal, stati...
# 1    stickers, food stickers, bullet journal, stati...
# ..                                                 ...
# 281  sticker flakes stickers, food stickers, bullet...
# 282  sticker flakes stickers, food stickers, bullet...
#
# [283 rows x 13 columns]

# %%
#convert dates to datetime objects
all_df['Sale Date'] = pd.to_datetime(all_df['Sale Date'], format='%m/%d/%y')
all_df['Date Shipped'] = pd.to_datetime(all_df['Date Shipped'], format='%m/%d/%Y')

# %%
#sort dataframe by order date
all_df = all_df.sort_values(by='Sale Date', ascending=True)
all_df = all_df.reset_index(drop=True)

# %%
print("Number of rows in orders_df:", len(orders_df))
print("Number of rows in reviews_df:", len(reviews_df))
print("Number of rows in all_df:", len(all_df))
# Out:
# Number of rows in orders_df: 266
# Number of rows in reviews_df: 83
# Number of rows in all_df: 283

# %%
#drop duplicate rows generated by merge, reset index
duplicate_indexes = [10, 11, 21, 22, 48, 51, 115, 117, 120, 125, 126, 236, 237, 238, 239, 241, 242]
all_df = all_df.drop(duplicate_indexes)

# %%
all_df = all_df.reset_index(drop=True)

# %%
print("Number of rows in orders_df:", len(orders_df))
print("Number of rows in reviews_df:", len(reviews_df))
print("Number of rows in all_df:", len(all_df))
# Out:
# Number of rows in orders_df: 266
# Number of rows in reviews_df: 83
# Number of rows in all_df: 266

# %%
print(all_df['Ship State'].unique())
# Out:
# ['CA' 'GA' 'TX' 'FL' 'AZ' 'MI' 'WA' 'OR' 'NJ' 'PA' 'MA' 'TN' 'NE' 'HI'
#  'MD' 'KY' 'NC' 'NY' 'IL' 'CO' 'WI' 'OH' 'MO' 'OK' 'MN' 'VA' 'IN'
#  'Lancashire' 'Kent' 'NSW' 'ON' nan 'Okinawa' 'NV' 'ND' 'ID' 'AK' 'SC']

# %%
#convert state and country names to usable format 
all_df[all_df['Ship State'].isin(['Lancashire', 'Kent','NSW', 'Okinawa']) | all_df['Ship State'].isna()]
all_df.iloc[119, all_df.columns.get_loc('Ship State')] = np.nan
all_df.iloc[138, all_df.columns.get_loc('Ship State')] = np.nan
all_df.iloc[139, all_df.columns.get_loc('Ship State')] = np.nan
all_df.iloc[168, all_df.columns.get_loc('Ship State')] = np.nan

# %%
all_df[all_df['Ship State'].isin(['Lancashire', 'Kent','NSW', 'Okinawa']) | all_df['Ship State'].isna()]
# Out:
#      Sale Date  Quantity  Price  Item Total Date Shipped         Ship Name  \
# 119 2021-04-06         1   3.30        3.30   2021-04-13    Lilia Williams
# 138 2021-05-15         1   3.25        3.25   2021-05-19       Kiah McCann
# 139 2021-05-19         1   4.50        4.50   2021-05-23   Michael Bradley
# 151 2021-06-21         1   3.00        3.00   2021-06-24  Gobega Sritharan
# 168 2021-08-12         2   3.00        6.00   2021-08-18    Elena Gushiken
#
#     Ship State    Ship Country  Variations  Rating  \
# 119        NaN  United Kingdom         NaN     NaN
# 138        NaN  United Kingdom         NaN     NaN
# 139        NaN       Australia  Size:Small     NaN
# 151        NaN  United Kingdom         NaN     1.0
# 168        NaN           Japan         NaN     5.0
#
#                                                 Review  \
# 119                                                NaN
# 138                                                NaN
# 139                                                NaN
# 151    Still not arrived - disappointed in the service
# 168  I felt like I was opening a letter of an old f...
#
#                           Item  \
# 119             Breakfast Time
# 138   Journey Into Outer Space
# 139             Quali-Tea Boba
# 151  Back To School Essentials
# 168  Back To School Essentials
#
#                                                   Tags
# 119  sticker flakes stickers, food stickers, bullet...
# 138  sticker flakes, stickers, planet stickers, bul...
# 139  sticker flakes, stickers, boba stickers, bulle...
# 151  sticker flakes, stickers, school stickers, bul...
# 168  sticker flakes, stickers, school stickers, bul...

# %%
#replace state abbreviations with full state names
state_mapping = {
    'AL': 'Alabama',
    'AK': 'Alaska',
    'AZ': 'Arizona',
    'AR': 'Arkansas',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'IA': 'Iowa',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'ME': 'Maine',
    'MD': 'Maryland',
    'MA': 'Massachusetts',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MS': 'Mississippi',
    'MO': 'Missouri',
    'MT': 'Montana',
    'NE': 'Nebraska',
    'NV': 'Nevada',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NY': 'New York',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VT': 'Vermont',
    'VA': 'Virginia',
    'WA': 'Washington',
    'WV': 'West Virginia',
    'WI': 'Wisconsin',
    'WY': 'Wyoming'
}

all_df['Ship State'] = all_df['Ship State'].map(state_mapping)

# %%
all_df['Ship State']
# Out:
# 0      California
# 1         Georgia
#           ...
# 264    California
# 265      Illinois
# Name: Ship State, Length: 266, dtype: object

# %% [markdown]
# **Sales Trend Analysis: Understanding sales patterns and identify trends**
# -
# - Compare sales performance year-over-year and month-over-month
# - Visualize sales trends over time using line chart, bar graph, heat map

# %%
all_df['Sale Month'] = all_df['Sale Date'].dt.month
all_df['Sale Year'] = all_df['Sale Date'].dt.year

# %%
month_count_df = all_df.groupby('Sale Month').count()['Item Total'].reset_index()

# %%
month_count_df
# Out:
#     Sale Month  Item Total
# 0            1          27
# 1            2          15
# ..         ...         ...
# 10          11          27
# 11          12          44
#
# [12 rows x 2 columns]

# %%
month_mapping = {
    1: 'January', 2: 'February', 3: 'March', 4: 'April',
    5: 'May', 6: 'June', 7: 'July', 8: 'August',
    9: 'September', 10: 'October', 11: 'November', 12: 'December'
}
month_count_df['Sale Month'] = month_count_df['Sale Month'].map(month_mapping)

# %%
month_count_df = month_count_df.set_index('Sale Month')

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(x=month_count_df.index, y='Item Total', data=month_count_df, color="#9ED0E6")

for index, row in month_count_df.iterrows():
    plt.text(index, row['Item Total'] + 1, row['Item Total'], color='black', ha="center")

plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.xticks(rotation=0)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %%
year_month_count_df = all_df.groupby(['Sale Year', 'Sale Month']).count()['Item Total'].to_frame()

#fill in missing data
new_row = pd.DataFrame({'Item Total': [0]}, index=pd.MultiIndex.from_tuples([(2023, 3)], names=['Sale Year', 'Sale Month']))
year_month_count_df = pd.concat([year_month_count_df, new_row])

new_row = pd.DataFrame({'Item Total': [0]}, index=pd.MultiIndex.from_tuples([(2023, 4)], names=['Sale Year', 'Sale Month']))
year_month_count_df = pd.concat([year_month_count_df, new_row])

# %%
year_month_count_df = year_month_count_df.reset_index().sort_values(by=['Sale Year', 'Sale Month'], ascending=[True, True])

# %%
year_month_count_df['Sale Month'] = year_month_count_df['Sale Month'].map(month_mapping)

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
year_month_count_df['Sale Month'] = pd.Categorical(year_month_count_df['Sale Month'], categories=month_order, ordered=True)
year_month_count_df
year_month_count_df = year_month_count_df.sort_values(by=['Sale Year', 'Sale Month'])

# %%
year_month_count_df
# Out:
#     Sale Year Sale Month  Item Total
# 0        2020       July           4
# 1        2020     August          13
# ..        ...        ...         ...
# 32       2023        May           1
# 33       2023       June           1
#
# [36 rows x 3 columns]

# %%
plt.figure(figsize=(12, 6))

year_month_count_colors = sns.color_palette(['#9ED0E6', '#004666', '#9A85A1', '#EBD2ED'])

sns.lineplot(data=year_month_count_df, x='Sale Month', y='Item Total', hue='Sale Year', marker='o', palette=year_month_count_colors)

plt.title('Monthly Sales Over Four Years')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.legend(title='Year')
plt.show()

# %% [markdown]
# **Product Performance Analysis: Assess the performance of individual items**
# -
# - Analyze which products are the best-sellers and which have low sales
# - Determine the average rating for each product
# - Visualize product performance using pie chart and bar graph

# %%
pd.set_option('display.max_rows', 10)

# %%
items_count_series = all_df.groupby('Item').count().sort_values(by='Item Total', ascending=True)['Item Total']
items_count_df = items_count_series.to_frame(name='Item Total')

# %%
items_count_df
# Out:
#                            Item Total
# Item
# Holiday Cookies                     7
# 31 Days Of Boba                     9
# A Starry Christmas                 27
# Journey Into Outer Space           35
# Back To School Essentials          45
# Quali-Tea Boba                     47
# Breakfast Time                     96

# %%
items_count_colors = ['#E3E7EC', '#1E1252', '#EBD2ED', '#004666', '#715F8E', '#9ED0E6', '#9A85A1']

plt.figure(figsize=(5,5))
plt.pie(items_count_df['Item Total'], labels=items_count_df.index, autopct='%1.1f%%', startangle=140, colors=items_count_colors)
plt.title('Percentage of Sales By Item')
plt.axis('equal')
plt.show()

# %%
items_rating_df = all_df.dropna(subset=['Rating']).get(['Rating','Item'])
items_rating_df = items_rating_df.groupby('Item').mean().round(2).sort_values(by='Rating', ascending=False)
items_rating_df
# Out:
#                            Rating
# Item
# 31 Days Of Boba              5.00
# Holiday Cookies              5.00
# Journey Into Outer Space     4.93
# Breakfast Time               4.91
# A Starry Christmas           4.90
# Quali-Tea Boba               4.87
# Back To School Essentials    4.67

# %%
items_ratings_colors = ['#1E1252','#E3E7EC','#004666','#9A85A1', '#EBD2ED', '#9ED0E6', '#715F8E']

#create the figure and axes
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(14, 8), gridspec_kw={'height_ratios': [4, 1]})
fig.subplots_adjust(hspace=0.05)  # Adjust space between axes

#plot the data on both axes
sns.barplot(x=items_rating_df.index, y='Rating', data=items_rating_df, palette=items_ratings_colors, ax=ax1)
sns.barplot(x=items_rating_df.index, y='Rating', data=items_rating_df, palette=items_ratings_colors, ax=ax2)

#set different scales
ax1.set_ylim(4, 5)  #top plot
ax2.set_ylim(0, 4)  #bottom plot

#hide the spines between ax1 and ax2
ax1.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax1.tick_params(labeltop=False, labelbottom=False, bottom=False)
ax2.xaxis.tick_bottom()

#add diagonal lines to indicate the break
d = 0.5  #proportion of vertical to horizontal extent of the slanted line
kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12,
              linestyle="none", color='k', mec='k', mew=1, clip_on=False)
ax1.plot([0, 1], [0, 0], transform=ax1.transAxes, **kwargs)
ax2.plot([0, 1], [1, 1], transform=ax2.transAxes, **kwargs)

#set labels and title
ax2.set_xlabel('Product', fontsize=12)
ax1.set_ylabel('Rating', fontsize=12)
ax2.set_ylabel('')
plt.suptitle('Product Ratings', fontsize=16)

#annotate each bar with the rating value (only in the top plot)
for i, row in items_rating_df.iterrows():
    ax1.text(i, row['Rating'] + 0.01, f"{row['Rating']:.2f}", ha='center', va='bottom')

#remove top and right spines
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax2.spines['right'].set_visible(False)

#adjust x-axis labels
plt.setp(ax2.get_xticklabels(), rotation=0, ha='center')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\sarah\AppData\Local\Temp\ipykernel_12420\2790644309.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=items_rating_df.index, y='Rating', data=items_rating_df, palette=items_ratings_colors, ax=ax1)
# C:\Users\sarah\AppData\Local\Temp\ipykernel_12420\2790644309.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=items_rating_df.index, y='Rating', data=items_rating_df, palette=items_ratings_colors, ax=ax2)

# %% [markdown]
# **Customer Feedback Analysis: Understand customer sentiment and identify areas for improvement**
# -
# - Identify common themes and keywords in customer feedback using word cloud and sentiment score chart
# - Calculate average processing time for orders
# - Visualize regions at various sales levels using heat map

# %%
all_df
# Out:
#      Sale Date  Quantity  Price  Item Total Date Shipped  \
# 0   2020-07-17         1   3.30        3.30   2020-07-20
# 1   2020-07-18         1   3.25        3.25   2020-07-20
# 2   2020-07-25         1   4.50        4.50   2020-07-30
# 3   2020-07-26         1   4.50        4.50   2020-07-30
# 4   2020-08-02         1   3.30        3.30   2020-08-04
# ..         ...       ...    ...         ...          ...
# 261 2022-12-17         1   3.35        3.35   2022-12-25
# 262 2023-01-19         1   3.30        3.30   2023-01-28
# 263 2023-02-26         1   3.30        3.30   2023-03-05
# 264 2023-05-10         1   3.00        3.00   2023-05-13
# 265 2023-06-22         1   3.00        3.00   2023-08-07
#
#                 Ship Name      Ship State   Ship Country Variations  Rating  \
# 0               Tyler Lee      California  United States        NaN     NaN
# 1          Hope Abernathy         Georgia  United States        NaN     5.0
# 2                   Sam K      California  United States        NaN     NaN
# 3            Nicole Pryor           Texas  United States        NaN     NaN
# 4              Maisha Huq      California  United States        NaN     NaN
# ..                    ...             ...            ...        ...     ...
# 261          Tatum Powell         Georgia  United States        NaN     NaN
# 262           Teresa bone  South Carolina  United States        NaN     NaN
# 263    Tiffany SantaMaria         Arizona  United States        NaN     NaN
# 264            Marie Leon      California  United States        NaN     NaN
# 265  Domonique McCullough        Illinois  United States        NaN     5.0
#
#                                                 Review  \
# 0                                                  NaN
# 1    Love them so much!! They are so cute and awesome!
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 261                                                NaN
# 262                                                NaN
# 263                                                NaN
# 264                                                NaN
# 265  Revised: Seller reached out to me to send anot...
#
#                           Item  \
# 0               Breakfast Time
# 1     Journey Into Outer Space
# 2              31 Days Of Boba
# 3              31 Days Of Boba
# 4               Breakfast Time
# ..                         ...
# 261         A Starry Christmas
# 262             Breakfast Time
# 263             Breakfast Time
# 264  Back To School Essentials
# 265  Back To School Essentials
#
#                                                   Tags  Sale Month  Sale Year
# 0    stickers, food stickers, bullet journal, stati...           7       2020
# 1    stickers, planet stickers, bullet journal, sta...           7       2020
# 2    stickers, boba stickers, bullet journal, stati...           7       2020
# 3    stickers, boba stickers, bullet journal, stati...           7       2020
# 4    stickers, food stickers, bullet journal, stati...           8       2020
# ..                                                 ...         ...        ...
# 261  sticker flakes, stickers, christmas stickers, ...          12       2022
# 262  sticker flakes stickers, food stickers, bullet...           1       2023
# 263  sticker flakes stickers, food stickers, bullet...           2       2023
# 264  sticker flakes, stickers, school stickers, bul...           5       2023
# 265  sticker flakes, stickers, school stickers, bul...           6       2023
#
# [266 rows x 15 columns]

# %%
all_df['Processing Time'] = (all_df['Date Shipped'] - all_df['Sale Date']).dt.days

# %%
print("The average processing time between an order is placed and when it is shipped out is " + str(round(all_df['Processing Time'].mean(),2)) + " days.")
# Out:
# The average processing time between an order is placed and when it is shipped out is 5.68 days.

# %%
all_reviews_text = ' '.join(all_df['Review'].dropna().astype(str).values)

# %%
wordcloud_colors = ['#1E1252', '#004666','#9A85A1', '#EBD2ED', '#9ED0E6', '#715F8E']

def custom_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return random.choice(wordcloud_colors)

#generate the word cloud
wordcloud = WordCloud(width=800, height=400, color_func=custom_color_func, background_color='white').generate(all_reviews_text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  #hide the axes
plt.show()

# %%
all_df
# Out:
#      Sale Date  Quantity  Price  Item Total Date Shipped  \
# 0   2020-07-17         1   3.30        3.30   2020-07-20
# 1   2020-07-18         1   3.25        3.25   2020-07-20
# 2   2020-07-25         1   4.50        4.50   2020-07-30
# 3   2020-07-26         1   4.50        4.50   2020-07-30
# 4   2020-08-02         1   3.30        3.30   2020-08-04
# ..         ...       ...    ...         ...          ...
# 261 2022-12-17         1   3.35        3.35   2022-12-25
# 262 2023-01-19         1   3.30        3.30   2023-01-28
# 263 2023-02-26         1   3.30        3.30   2023-03-05
# 264 2023-05-10         1   3.00        3.00   2023-05-13
# 265 2023-06-22         1   3.00        3.00   2023-08-07
#
#                 Ship Name      Ship State  ...  \
# 0               Tyler Lee      California  ...
# 1          Hope Abernathy         Georgia  ...
# 2                   Sam K      California  ...
# 3            Nicole Pryor           Texas  ...
# 4              Maisha Huq      California  ...
# ..                    ...             ...  ...
# 261          Tatum Powell         Georgia  ...
# 262           Teresa bone  South Carolina  ...
# 263    Tiffany SantaMaria         Arizona  ...
# 264            Marie Leon      California  ...
# 265  Domonique McCullough        Illinois  ...
#
#                                                   Tags Sale Month  Sale Year  \
# 0    stickers, food stickers, bullet journal, stati...          7       2020
# 1    stickers, planet stickers, bullet journal, sta...          7       2020
# 2    stickers, boba stickers, bullet journal, stati...          7       2020
# 3    stickers, boba stickers, bullet journal, stati...          7       2020
# 4    stickers, food stickers, bullet journal, stati...          8       2020
# ..                                                 ...        ...        ...
# 261  sticker flakes, stickers, christmas stickers, ...         12       2022
# 262  sticker flakes stickers, food stickers, bullet...          1       2023
# 263  sticker flakes stickers, food stickers, bullet...          2       2023
# 264  sticker flakes, stickers, school stickers, bul...          5       2023
# 265  sticker flakes, stickers, school stickers, bul...          6       2023
#
#     Processing Time Review Category Sentiment  Sentiment Category
# 0                 3             NaN       NaN                 NaN
# 1                 2         Product  0.578125            Positive
# 2                 5             NaN       NaN                 NaN
# 3                 4             NaN       NaN                 NaN
# 4                 2             NaN       NaN                 NaN
# ..              ...             ...       ...                 ...
# 261               8             NaN       NaN                 NaN
# 262               9             NaN       NaN                 NaN
# 263               7             NaN       NaN                 NaN
# 264               3             NaN       NaN                 NaN
# 265              46         Service  0.413333            Positive
#
# [266 rows x 19 columns]

# %%
#determine review category
def determine_review_category(text):
    if text.strip() != '':
        if 'service' in text.lower():
            return 'Service'
        if 'ship' in text.lower():
            return 'Shipping'
        else:
            return 'Product'
    else:
        return np.nan

all_df['Review Category'] = all_df['Review'].dropna().apply(determine_review_category)

# %%
#function to calculate sentiment polarity using TextBlob
def calculate_sentiment(text):
    if text.strip() != '':
        analysis = TextBlob(text)
        return analysis.sentiment.polarity
    else:
        return np.nan

#apply sentiment analysis to each row of text data
all_df['Sentiment'] = all_df['Review'].dropna().apply(calculate_sentiment)

# %%
#function to determine sentiment category
def determine_sentiment(score):
    if score >= 0.3:
        return 'Positive'
    elif score >= -0.3:
        return 'Neutral'
    elif score < -0.3:
        return 'Negative'
    else:
        return np.nan

#apply sentiment analysis to each row of text data
all_df['Sentiment Category'] = all_df['Sentiment'].dropna().apply(determine_sentiment)

# %%
#aggregate sentiment scores by category
sentiment_by_category_series = all_df.groupby('Review Category')['Sentiment'].mean()

# %%
sentiment_by_category_df = round(sentiment_by_category_series, 2).to_frame()

# %%
#function to count sentiment category for each sentiment
def count_sentiment(review, sentiment):
    return int(all_df[(all_df['Review Category'] == review) & (all_df['Sentiment Category'] == sentiment)].shape[0])

#apply to each sentiment
sentiment_by_category_df.loc['Product', 'Positive'] = count_sentiment('Product', 'Positive')
sentiment_by_category_df.loc['Product', 'Neutral'] = count_sentiment('Product', 'Neutral')
sentiment_by_category_df.loc['Product', 'Negative'] = count_sentiment('Product', 'Negative')
sentiment_by_category_df.loc['Service', 'Positive'] = count_sentiment('Service', 'Positive')
sentiment_by_category_df.loc['Service', 'Neutral'] = count_sentiment('Service', 'Neutral')
sentiment_by_category_df.loc['Service', 'Negative'] = count_sentiment('Service', 'Negative')
sentiment_by_category_df.loc['Shipping', 'Positive'] = count_sentiment('Shipping', 'Positive')
sentiment_by_category_df.loc['Shipping', 'Neutral'] = count_sentiment('Shipping', 'Neutral')
sentiment_by_category_df.loc['Shipping', 'Negative'] = count_sentiment('Shipping', 'Negative')

# %%
sentiment_by_category_df
# Out:
#                  Sentiment  Positive  Neutral  Negative
# Review Category
# Product               0.47      43.0      5.0       0.0
# Service               0.37       3.0      0.0       1.0
# Shipping              0.28       4.0      2.0       0.0

# %%
plt.figure(figsize=(10, 6))
fig, ax = plt.subplots()
bars = ax.bar(sentiment_by_category_df.index, sentiment_by_category_df['Sentiment'], color='#9A85A1')

plt.title('Average Sentiment Score by Category', fontsize=16)
plt.xlabel('Category', fontsize=12)
plt.ylabel('Average Sentiment Score', fontsize=12)
plt.xticks(rotation=0)

#annotate each bar with the rating value (only in the top plot)
for i, row in sentiment_by_category_df.iterrows():
    ax.text(i, row['Sentiment'] + 0.01, f"{row['Sentiment']:.2f}", ha='center', va='bottom')

#remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.set_ylim(-1, 1)
ax.axhline(0, color='black', linewidth=0.8)

plt.show()

# %%
print(all_df['Ship State'].unique())
# Out:
# ['California' 'Georgia' 'Texas' 'Florida' 'Arizona' 'Michigan'
#  'Washington' 'Oregon' 'New Jersey' 'Pennsylvania' 'Massachusetts'
#  'Tennessee' 'Nebraska' 'Hawaii' 'Maryland' 'Kentucky' 'North Carolina'
#  'New York' 'Illinois' 'Colorado' 'Wisconsin' 'Ohio' 'Missouri' 'Oklahoma'
#  'Minnesota' 'Virginia' 'Indiana' nan 'Nevada' 'North Dakota' 'Idaho'
#  'Alaska' 'South Carolina']

# %%
state_count_series = all_df.groupby('Ship State').count().dropna().sort_values(by='Item Total', ascending=True)['Item Total']
state_count_df = state_count_series.to_frame(name='Item Total').reset_index()
countries_count_series= all_df.groupby('Ship Country').count().sort_values(by='Item Total', ascending=True)['Item Total']
countries_count_df = countries_count_series.to_frame(name='Item Total').reset_index()
countries_count_df.loc[4, 'Ship Country'] = 'United States of America'

# %%
#load the shapefile for all countries
countries_shapefile_path = 'D:/Code/Starry-Sticker-Shop-Analysis/ne_110m_admin_0_countries/ne_110m_admin_0_countries.shp'
countries_gdf = gpd.read_file(countries_shapefile_path)

#merge the GeoDataFrame with the intensity data
countries_gdf = countries_gdf.merge(countries_count_df, how='left', left_on='SOVEREIGNT', right_on='Ship Country')

#determine outlier threshold
outlier_threshold = 4
outlier_color = '#1E1252'

#define colormap for majority of data
colors = ['#ebd2ed', '#715f8e']  #colors for majority data
cmap = LinearSegmentedColormap.from_list('custom_cmap', colors, N=256)
#plotting
fig, ax = plt.subplots(figsize=(12, 5))

#normalize data excluding outliers
norm = Normalize(vmin=countries_gdf['Item Total'].min(), vmax=outlier_threshold)

#plot GeoDataFrame excluding outliers with majority colormap
countries_gdf[countries_gdf['Item Total'] <= outlier_threshold].plot(column='Item Total', cmap=cmap, linewidth=0.8, ax=ax, edgecolor='gray', legend=True, norm=norm)

#plot outliers separately with specified color
countries_gdf[countries_gdf['Item Total'] > outlier_threshold].plot(column='Item Total', color=outlier_color, linewidth=0.8, ax=ax, edgecolor='gray', legend=True)

#customize plot settings
ax.set_aspect('auto')
ax.set_title('Sticker Shop Sale By Location')
ax.set_axis_off()

#manually add legend for outlier color
legend_elements = [Patch(facecolor=outlier_color, edgecolor='black', label='257')]
ax.legend(handles=legend_elements, loc='upper right')

plt.show()
# Out:
# C:\Users\sarah\AppData\Local\Temp\ipykernel_12420\33443811.py:25: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   countries_gdf[countries_gdf['Item Total'] > outlier_threshold].plot(column='Item Total', color=outlier_color, linewidth=0.8, ax=ax, edgecolor='gray', legend=True)

# %%
#load the shapefile for US states
#update the path to the location of the extracted shapefile on your system
us_shapefile_path = 'D:/Code/Starry-Sticker-Shop-Analysis/ne_110m_admin_1_states_provinces/ne_110m_admin_1_states_provinces.shp'
us_gdf = gpd.read_file(us_shapefile_path)

#merge the GeoDataFrame with the intensity data
us_gdf = us_gdf.merge(state_count_df, how='left', left_on='name', right_on='Ship State')

#determine outlier threshold
outlier_threshold = 18
outlier_color = '#1E1252'

#define colormap for majority of data
colors = ['#9ed0e6', '#004666']  #colors for majority data
cmap = LinearSegmentedColormap.from_list('custom_cmap', colors, N=256)

#normalize data excluding outliers
norm = Normalize(vmin=us_gdf['Item Total'].min(), vmax=outlier_threshold)

#plotting
fig, ax = plt.subplots(figsize=(12, 5))

#plot state boundaries with a light color
us_gdf.boundary.plot(ax=ax, linewidth=0.8, color='gray')

#plot GeoDataFrame excluding outliers with majority colormap
us_gdf[us_gdf['Item Total'] <= outlier_threshold].plot(column='Item Total', cmap=cmap, linewidth=0.8, ax=ax, edgecolor='gray', legend=True, norm=norm)

#plot outliers separately with specified color
us_gdf[us_gdf['Item Total'] > outlier_threshold].plot(column='Item Total', color=outlier_color, linewidth=0.8, ax=ax, edgecolor='gray', legend=True)

#customize plot settings
ax.set_title('Sticker Shop Sale in United States', fontsize=16)
ax.set_axis_off()

#manually add legend for outlier color
legend_elements = [Patch(facecolor=outlier_color, edgecolor='black', label='79')]
ax.legend(handles=legend_elements, loc='upper right')

plt.show()
# Out:
# C:\Users\sarah\AppData\Local\Temp\ipykernel_12420\3727490881.py:30: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   us_gdf[us_gdf['Item Total'] > outlier_threshold].plot(column='Item Total', color=outlier_color, linewidth=0.8, ax=ax, edgecolor='gray', legend=True)

# %% [markdown]
# **Exporting data for Tableau**
# -

# %%
all_df.to_csv('all_data.csv', index=False)

# %%
words = all_reviews_text.split()
meaningful_words = [word for word in words if word.lower() not in ENGLISH_STOP_WORDS]
word_counts = Counter(meaningful_words)
review_count_df = pd.DataFrame.from_dict(word_counts, orient='index', columns=['Frequency'])
review_count_df = review_count_df.sort_values(by='Frequency', ascending=False).reset_index()

# %%
review_count_df.to_csv('review_count.csv', index=False)

# %%
state_count_df.to_csv('state_count.csv', index=False)

# %%
sentiment_by_category_df = sentiment_by_category_df.reset_index()
sentiment_by_category_df.to_csv('sentiment_category.csv', index=False)
